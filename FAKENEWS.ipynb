# %% [markdown]
# <a href="https://colab.research.google.com/github/samurai5634/COdes/blob/main/FAKENEWS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv('/content/True.csv', on_bad_lines='skip')

# %%
false = pd.read_csv('/content/Fake.csv', on_bad_lines='skip')

# %%
true.head(10)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
# 6  Trump says Russia probe will be fair, but time...
# 7  Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8         Trump on Twitter (Dec 28) - Global Warming
# 9  Alabama official to certify Senator-elect Jone...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# ...

# %%
 true['label'] = 1

# %%
false['label'] = 0

# %%
true.head(10)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
# 6  Trump says Russia probe will be fair, but time...
# 7  Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8         Trump on Twitter (Dec 28) - Global Warming
# 9  Alabama official to certify Senator-elect Jone...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# ...

# %%
false.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
news = pd.concat([true, false], axis = 0)

# %%
news.head(10)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
# 6  Trump says Russia probe will be fair, but time...
# 7  Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8         Trump on Twitter (Dec 28) - Global Warming
# 9  Alabama official to certify Senator-elect Jone...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# ...

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news.isnull()
# Out:
#        title   text  subject   date  label
# 0      False  False    False  False  False
# 1      False  False    False  False  False
# 2      False  False    False  False  False
# 3      False  False    False  False  False
# 4      False  False    False  False  False
# ...      ...    ...      ...    ...    ...
# 23476  False  False    False  False  False
# 23477  False  False    False  False  False
# 23478  False  False    False  False  False
# 23479  False  False    False  False  False
# 23480  False  False    False  False  False
#
# [44898 rows x 5 columns]

# %%
news.drop(['title','date','subject'],axis = 1, inplace = True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  WASHINGTON (Reuters) - The head of a conservat...      1
# 1  WASHINGTON (Reuters) - Transgender people will...      1
# 2  WASHINGTON (Reuters) - The special counsel inv...      1
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...      1
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...      1

# %%
news = news.sample(frac=1)

# %%
news.head()
# Out:
#                                                     text  label
# 7112   WASHINGTON (Reuters) - President-elect Donald ...      1
# 3105   WASHINGTON (Reuters) - U.S. Attorney General J...      1
# 11322  NEW YORK (Reuters) - New York City has quietly...      1
# 17517  In September 2016, Stephen Henderson, the edit...      0
# 2002   WASHINGTON (Reuters) - White House adviser Seb...      1

# %%
news.reset_index(inplace = True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0   7112  WASHINGTON (Reuters) - President-elect Donald ...      1
# 1   3105  WASHINGTON (Reuters) - U.S. Attorney General J...      1
# 2  11322  NEW YORK (Reuters) - New York City has quietly...      1
# 3  17517  In September 2016, Stephen Henderson, the edit...      0
# 4   2002  WASHINGTON (Reuters) - White House adviser Seb...      1

# %%
news.drop(['index'],axis = 1, inplace = True)

# %%
import re
import string

def word(text):
  text = text.lower() # Convert text to lowercase
  text = re.sub('\[.*?\]', '', text) # Remove text in square brackets

  # Remove punctuation
  text = text.translate(str.maketrans('', '', string.punctuation))

  # Remove HTML tags
  text = re.sub(r'<.*?>', '', text)

  # Remove URLs
  text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

  # Remove digits
  text = re.sub(r'\d+', '', text)

  # Remove newline characters
  text = text.replace('\n', ' ')

  return text

# %%
news['text'] = news['text'].apply(word)

# %%
news['text']
# Out:
# 0        washington reuters  presidentelect donald trum...
# 1        washington reuters  us attorney general jeff s...
# 2        new york reuters  new york city has quietly be...
# 3        in september  stephen henderson the editorial ...
# 4        washington reuters  white house adviser sebast...
#                                ...
# 44893    berlin reuters  it is important for spain to u...
# 44894    united nations reuters  the united nations lau...
# 44895     i m convinced the freedom from religion group...
# 44896    washington reuters  the us supreme court has a...
# 44897    washington reuters  by us president donald tru...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorization = TfidfVectorizer()
v_train = vectorization.fit_transform(x_train)
v_test = vectorization.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(v_train, y_train)
# Out:
# LogisticRegression()

# %%
pred = LR.predict(v_test)

# %%
LR.score(v_test, y_test)
# Out:
# 0.9879732739420936

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5907
#            1       0.99      0.99      0.99      5318
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(v_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = DT.predict(v_test)

# %%
DT.score(v_test, y_test)
# Out:
# 0.99456570155902

# %%
print(classification_report(y_test, dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5907
#            1       0.99      0.99      0.99      5318
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
RF.fit(v_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rf = RF.predict(v_test)

# %%
RF.score(v_test, y_test)
# Out:
# 0.9869933184855234
